# %%
# !pip install langchain
# !pip install pypdf
# !pip install sentence-transformers
# !pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.9/815.9 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.0/284.0 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 44.7 MB/s eta 0:00:00
# ...

# %%
# !pip install ctransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 15.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip  /content/drive/MyDrive/BIRADs.zip
# Out:
# Archive:  /content/drive/MyDrive/BIRADs.zip
#    creating: BIRADs/
#    creating: BIRADs/BIRAD 0/
#   inflating: BIRADs/BIRAD 0/Report.pdf
#   inflating: BIRADs/BIRAD 0/Report18.pdf
#   inflating: BIRADs/BIRAD 0/Report28.pdf
#   inflating: BIRADs/BIRAD 0/Report53.pdf
#   inflating: BIRADs/BIRAD 0/Report92.pdf
#    creating: BIRADs/BIRAD I/
#   inflating: BIRADs/BIRAD I/Report101.pdf
#   inflating: BIRADs/BIRAD I/Report13.pdf
#   inflating: BIRADs/BIRAD I/Report14.pdf
#   inflating: BIRADs/BIRAD I/Report15.pdf
#   inflating: BIRADs/BIRAD I/Report16.pdf
#   inflating: BIRADs/BIRAD I/Report17.pdf
#   inflating: BIRADs/BIRAD I/Report19.pdf
#   inflating: BIRADs/BIRAD I/Report20.pdf
#   inflating: BIRADs/BIRAD I/Report23.pdf
#   inflating: BIRADs/BIRAD I/Report25.pdf
#   inflating: BIRADs/BIRAD I/Report27.pdf
#   inflating: BIRADs/BIRAD I/Report29.pdf
#   inflating: BIRADs/BIRAD I/Report30.pdf
#   inflating: BIRADs/BIRAD I/Report31.pdf
#   inflating: BIRADs/BIRAD I/Report33.pdf
# ...

# %%
import sys
sys.path.append('/content/drive/MyDrive/health/llm1')

# %%
# !python /content/drive/MyDrive/health/llm1/ingest.py
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/vectorstores/__init__.py:35: LangChainDeprecationWarning: Importing vector stores from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.vectorstores import FAISS`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/document_loaders/__init__.py:36: LangChainDeprecationWarning: Importing document loaders from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.document_loaders import PyPDFLoader`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# ...

# %%
# !python /content/drive/MyDrive/health/llm1/main.py
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/embeddings/__init__.py:29: LangChainDeprecationWarning: Importing embeddings from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.embeddings import HuggingFaceEmbeddings`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/vectorstores/__init__.py:35: LangChainDeprecationWarning: Importing vector stores from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.vectorstores import FAISS`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# ...

# %%
import os
import shutil
import timeit
import argparse
from wrapper import setup_qa_chain
from wrapper import query_embeddings
import pandas as pd
columns = ['file', 'answer']

def move_pdf_files():
    df = pd.DataFrame(columns=columns)
    # Define the source folder
    source_folder = "/content/BIRADs/BIRAD I"

    # Define the destination folder
    destination_folder = "/content/data"

    # Check if the data folder exists, create it if not
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Loop through each file in the source folder
    for file_name in os.listdir(source_folder):
        if file_name.endswith(".pdf"):
            if not os.path.exists(destination_folder):
                   os.makedirs(destination_folder)
            # Construct the source and destination paths
            source_path = os.path.join(source_folder, file_name)
            destination_path = os.path.join(destination_folder, file_name)

            # Move the PDF file to the data folder
            shutil.move(source_path, destination_path)
            print(f"Moved {file_name} to {destination_folder}")
            # !python /content/drive/MyDrive/health/llm1/ingest.py
            qa_chain = setup_qa_chain()
            response = qa_chain({'query': "What is type of BI-RADs, just return one value,. format response as following \"type\": {}"})
            print(f'\n{response["result"]}')
            new_row = {'file': file_name, 'answer': response["result"]}
            df = df.append(new_row, ignore_index=True)


    # Delete the data folder and its contents
            shutil.rmtree(destination_folder)
            print(f"Deleted {destination_folder} and its contents")

    # Define the path to the vector database
            vector_database_path = "/content/vectorstore"

    # Delete the vector database and its subfolders
            shutil.rmtree(vector_database_path)
    return df

# Call the function to execute the operations
df=move_pdf_files()
df.to_csv('/content/drive/MyDrive/health/I.csv')
# Out:
# Moved Report7.pdf to /content/data
# /usr/local/lib/python3.10/dist-packages/langchain/vectorstores/__init__.py:35: LangChainDeprecationWarning: Importing vector stores from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.vectorstores import FAISS`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/document_loaders/__init__.py:36: LangChainDeprecationWarning: Importing document loaders from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.document_loaders import PyPDFLoader`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# ...

# %%
#folder 0
1- 2
2-skip
3-skip
4-skip


#folder V
1-5


#folder IV
1-4
2-4
3-IVa
4-BI-RADS IV
5-4A
6-2 wrong answer
7-IV
8-4

#folder III
1-III
2-Type 3
3-Category 3
4-type: 4C
5-"type": {value}
6-Category 3
7-Bilateral heterogeneous breasts with suspicious right breast mass lesion…BI-RADs III…For US assessment
8-type: 3
9-"Type:" Category 3
10-Type: BI-RADs® Category 3


#folder II
1-Type: 2
2-"type": "I"
3-Hanan.
4-type: 3
5-"type": 1
